# %% [markdown]
# ## Imports and setup
#
# This notebook is in a customized project and requires a custumized python module (.py file) to run. By default the path to the start module for a custom project is ./src/"project_name"; it needs to contain a startup function. The default name of that function is "Run_process". In this project, [AI4SH](https://ai4soilhealth.eu), the path to the custom project is ./src/ai4sh and the first cell calls the Run_process function in that package.

# %%
## Standard library imports
from os import path, getcwd

import sys 

# Get the working directory of the notebook
notebook_path = getcwd()

# Set the path to the root directory of this jupyter notebook (python) project
module_path = path.abspath(path.join('../..'))

if module_path not in sys.path:
    
    sys.path.append(module_path)

# Package application imports
from src.lib import Initiate_process

# Import the custom class for running processes defined in the claude package
from src.ai4sh import Run_process

# %% [markdown]
# ## Scheme file
# To run this cell you need to set the [scheme_file](https://xspatula.github.io/setup_core_db_docs/framework/scheme_file/), that defines the location (path) to the project and associated process files and your user. You can set the path to the scheme file with a relative path (relative to this notebook), in your home directory using tilde (~) or with an absolute path in the syntax of your operating system.

# %%
# Set the path to the scheme_file  

scheme_file = '../scheme_lucas.json'

# %% [markdown]
# ## Detect indicator outliers
#
# Detect and select to remove outliers for individual indicators.

# %%
##%%script false --no-raise-error
process_file = 'project_lucas_2009/process/outlier_detection.json'

structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)

if structured_process_D is not None: 
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ../scheme_lucas.json
#
# ########### STARTING PROCESSES ###########
#
#     Outliers detected (threshold=0.100) — sand: 3  c-org: 3
#     Removed 6 outlier values across 2 indicators. Saved: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/lucas/project_lucas_2009/data/lucas_400-2500_10/data-foss xds rapid content analyzer_400-2500_10_ol.parquet
#
# ########### ALL PROCESSES FINISHED ###########

# %% [markdown]
# ## Meancentring
# Always good to start with meancentring

# %%
#%%script false --no-raise-error
process_file = 'project_lucas_2009/process/meancentring.json'

structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)

if structured_process_D is not None: 
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ../scheme_lucas.json
#
# ########### STARTING PROCESSES ###########
#     Saved: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/lucas/project_lucas_2009/data/lucas_400-2500_10/data-foss xds rapid content analyzer_400-2500_10_mc.parquet
#     Previous: spectra_scaling — data-foss xds rapid content analyzer_400-2500_10_mc.parquet
#     Saved: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/lucas/project_lucas_2009/data/lucas_400-2500_10/data-foss xds rapid content analyzer_400-2500_10_mc_snv.parquet
#
# ########### ALL PROCESSES FINISHED ###########

# %% [markdown]
# ## Select spectral bands from variance to reduce overfitting
# The selected bands will be saved as a new dataframe on your local machine

# %%
# %%script false --no-raise-error
# process_file = 'project_lucas_2009/process/variance_threshold_selection.json'
#
# structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)
#
# if structured_process_D is not None:
#
#     Run_process(structured_process_D, scheme_params_D)

# %% [markdown]
# ## Chemometric scatter correction

# %%
# %%script false --no-raise-error
# process_file = 'project_neospectra/process/chemometric_scatter_correction.json'
#
# structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)
#
# if structured_process_D is not None:
#
#     Run_process(structured_process_D, scheme_params_D)

# %% [markdown]
# ## Chemometric derivatives on scatter correction

# %%
#%%script false --no-raise-error
process_file = 'project_lucas_2009/process/chemometric_derivatives.json'

structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)

if structured_process_D is not None:
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ../scheme_lucas.json
#
# ########### STARTING PROCESSES ###########
#     Saved: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/lucas/project_lucas_2009/data/lucas_400-2500_10/data-foss xds rapid content analyzer_400-2500_10_mc_d1.parquet
#
# ########### ALL PROCESSES FINISHED ###########

# %% [markdown]
# ## Chemometric decomposition on derivatives

# %%
#%%script false --no-raise-error
process_file = 'project_lucas_2009/process/chemometric_decomposition.json'

structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)

if structured_process_D is not None:
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ../scheme_lucas.json
#
# ########### STARTING PROCESSES ###########
#     Result discarded.
#
# ########### ALL PROCESSES FINISHED ###########

# %% [markdown]
# ## Chemometric chain

# %%
# %%script false --no-raise-error
# process_file = 'project_neospectra/process/chemometric_default_chain.json'
#
# structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)
#
# if structured_process_D is not None:
#
#     Run_process(structured_process_D, scheme_params_D)

# %% [markdown]
# ## Filter raw data

# %%
# %%script false --no-raise-error
# process_file = 'project_neospectra/process/filter_spectra.json'
#
# structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)
#
# if structured_process_D is not None:
#
#     Run_process(structured_process_D, scheme_params_D)

# %% [markdown]
# ## Agglomerate spectra using ward clustering

# %%
# %%script false --no-raise-error
# process_file = 'project_neospectra/process/agglomerate_spectra.json'
#
# structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)
#
# if structured_process_D is not None:
#
#     Run_process(structured_process_D, scheme_params_D)

# %% [markdown]
# ## Autoscale the ward clustered output

# %%
# %%script false --no-raise-error
# process_file = 'project_neospectra/process/autoscale_agglomeration_output.json'
#
# structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)
#
# if structured_process_D is not None:
#
#     Run_process(structured_process_D, scheme_params_D)

# %% [markdown]
# # Select best bands using univariate selector for indicators

# %%
# %%script false --no-raise-error
# process_file = 'project_neospectra/process/univariate_selection.json'
#
# structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)
#
# if structured_process_D is not None:
#
#     Run_process(structured_process_D, scheme_params_D)

# %% [markdown]
# ## Select best bands from permutation, RFE or decision tree

# %%
# %%script false --no-raise-error
# process_file = 'project_neospectra/process/permutation_selector.json'
#
# structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)
#
# if structured_process_D is not None:
#
#     Run_process(structured_process_D, scheme_params_D)

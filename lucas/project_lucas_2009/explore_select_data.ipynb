# %% [markdown]
# ## Imports and setup
#
# This notebook is in a customized project and requires a custumized python module (.py file) to run. By default the path to the start module for a custom project is ./src/"project_name"; it needs to contain a startup function. The default name of that function is "Run_process". In this project, [AI4SH](https://ai4soilhealth.eu), the path to the custom project is ./src/ai4sh and the first cell calls the Run_process function in that package.

# %%
# Standard library imports
from os import path, getcwd

import sys 

# Get the working directory of the notebook
notebook_path = getcwd()

# Set the path to the root directory of this jupyter notebook (python) project
module_path = path.abspath(path.join('../..'))

if module_path not in sys.path:
    
    sys.path.append(module_path)

# Package application imports
from src.lib import Initiate_process

# Import the custom class for running processes defined in the ai4sh package
from src.ai4sh import Run_process

# %% [markdown]
# ## Scheme file
# To run this cell you need to set the [scheme_file](https://xspatula.github.io/setup_core_db_docs/framework/scheme_file/), that defines the location (path) to the project and associated process files and your user. You can set the path to the scheme file with a relative path (relative to this notebook), in your home directory using tilde (~) or with an absolute path in the syntax of your operating system.

# %%
# Set the path to the scheme_file  

scheme_file = '../scheme_lucas.json'

# %% [markdown]
# ## Find the available indicators for a defined dataset or campaign

# %%
#%%script false --no-raise-error
process_file = 'project_lucas_2009/process/select_indicator.json'

structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)

if structured_process_D is not None: 
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ../scheme_lucas.json
#
# ########### STARTING PROCESSES ###########
#
#
#     Querying available data for "lucas"
#
#     Spectral sensors (provisions):
#         - foss xds rapid content analyzer
#
#     Available indicators for "lucas":
#         - carbonate (caco3) [weight percent]
#         - cation exchange capacity (cec) [cmolc*kg^-1]
#         - clay (<0.002 mm) (clay) [weight percent]
#         - coarse fraction (cf) [weight percent]
#         - extractable phosphorus (p-ext) [mg*kg^-1]
#         - extractable pottassium (k-ext) [cmolc*kg^-1]
#         - organic carbon (c-org) [g*kg^-1]
#         - ph-cacl2 (ph-calcium-chloride) [ph]
#         - ph-h2o (ph-water) [ph]
#         - sand (0.06-2.0 mm) (sand) [weight percent]
#         - silt (0.002-0.06 mm) (silt) [weight percent]
#         - total nitrogen (n-tot) [weight percent]
#
# ########### ALL PROCESSES FINISHED ###########

# %% [markdown]
# ## Select spectra and analysis data to work with
# The selcted data will be saved to your local machine

# %%
#%%script false --no-raise-error
process_file = 'project_lucas_2009/process/select_lucas_2009_10nm.json'

structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)

if structured_process_D is not None: 
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ../scheme_lucas.json
#
# ########### STARTING PROCESSES ###########
#
#     Subset already exists, skipping: ./data/lucas_400-2500_10/data-foss xds rapid content analyzer_400-2500_10.parquet
#
# ########### ALL PROCESSES FINISHED ###########

# %% [markdown]
# ## Plot indicators

# %%
#%%script false --no-raise-error
process_file = 'project_lucas_2009/process/plot/plot_indicator.json'


structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)

if structured_process_D is not None:
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ../scheme_lucas.json
#
# ########### STARTING PROCESSES ###########
# ########### ALL PROCESSES FINISHED ###########

# %% [markdown]
# ## Plot spectra and scatter correction options

# %%
#%%script false --no-raise-error
process_file = 'project_lucas_2009/process/plot/plot_spectra_scattercorrection_scalers.json'

structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)

if structured_process_D is not None:
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ../scheme_lucas.json
#
# ########### STARTING PROCESSES ###########
# ########### ALL PROCESSES FINISHED ###########

# %% [markdown]
# ## Plot spectra and scaling method options

# %%
#%%script false --no-raise-error
process_file = 'project_lucas_2009/process/plot/plot_spectra_scaling_methods.json'

structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)

if structured_process_D is not None:
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ../scheme_lucas.json
#
# ########### STARTING PROCESSES ###########
# ########### ALL PROCESSES FINISHED ###########

# %% [markdown]
# ## Plot spectra

# %%
#%%script false --no-raise-error
process_file = 'project_lucas_2009/process/plot/plot_spectra.json'

structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)

if structured_process_D is not None:
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ../scheme_lucas.json
#
# ########### STARTING PROCESSES ###########
# ########### ALL PROCESSES FINISHED ###########

# %% [markdown]
# ## Plot filter spectra

# %%
#%%script false --no-raise-error
process_file = 'project_lucas_2009/process/plot/plot_filter_spectra.json'

structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, process_file)

if structured_process_D is not None:
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ../scheme_lucas.json
#
# ########### STARTING PROCESSES ###########
# ########### ALL PROCESSES FINISHED ###########

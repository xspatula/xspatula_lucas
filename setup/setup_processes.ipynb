# %% [markdown]
# ## Imports and setup
#
# The first cell creates a path to the notebook and imports the required library (`Initiate_process`) for running Xspatula. Leave it as it is and run it. For details see the online documentation on [Xspatula notebooks](https://xspatula.github.io/xspatula_core_docs/framework/notebook/).

# %%
# Standard library imports
from os import path, getcwd

import sys 

# Get the working directory of the notebook
notebook_path = getcwd()

# Set the path to the root directory of this jupyter notebook (python) project
module_path = path.abspath(path.join('..'))

if module_path not in sys.path:
    
    sys.path.append(module_path)

# Package application imports
from src.lib import Initiate_process 

from src_setup.lib_setup import Run_process

# %% [markdown]
# ## Scheme file
# To run this cell you need to set the [scheme_file](https://xspatula.github.io/xspatula_core_docs/framework/scheme_file/), that defines the location (path) to the project and associated process files, your user and the database to use. You can set the path to the scheme file with a relative path (relative to this notebook), in your home directory using tilde (~) or with an absolute path in the syntax of your operating system.

# %%
# Set the path to the scheme_file  

scheme_file = './zzz/scheme_local_use.json'

# %% [markdown]
# ## Setup processes
# [Xspatula LUCAS](https://xspatula.github.io/xspatula_lucas_docs/) includes all processes required for getting started with loading the database with soil data and for Machine Learning (ML). If you want to expand the processing capabilities  see the online documentation on [Setup Xspatula processes](https://xspatula.github.io/xspatula_core_docs/setup_processes/).
#
# **process**: add_process
#
# **job_file**: job_setup_processes.json

# %%
job_file = 'job_setup_processes.json'

structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, job_file)

if structured_process_D is not None:
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ./zzz/scheme_local_use.json
#
# . Using project/process file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/job_setup_processes.json
# .   Running <pilot_file>: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/setup_processes.txt
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/root_process/root_processes_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/translate/translate_tabular_data_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/translate/insert_tabular_data_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/utility/foreign_key_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/utility/territory_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/community/organisation_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/community/user_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/analysis_method_translate_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/analysis_method_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/apparatus_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/classification_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/indicator_default_unit_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/indicator_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/indicator_parity_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/juxtaposition_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/license_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/location_method_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/method_tier_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/preparation_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/preservation_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/profiling_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/provider_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/provision_indicator_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/provision_serial_nr_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/provision_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/quantity_default_unit_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/quantity_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/setting_system_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/spatial_reference_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/spectrometer_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/spectroscopy_method_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/storage_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/transportation_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/unit_translate_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/unit_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_sequence_library_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_nucleotide_archive_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_extraction_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_purification_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_amplification_v10_sql.json
# Error reading json file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_amplification_v10_sql.json
#   Expecting property name enclosed in double quotes: line 58 column 47 (char 1927)
#           ❌ ERROR: json file not read - skipping
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_sequencing_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_metabarcoding_pipeline_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/campaign_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/dataset_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/measurement_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/observation_log_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/observation_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/data_source_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/person_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/sample_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/sample_geolocation_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/sampling_log_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/campaign_tag_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/dataset_tag_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/crop_growth_stage_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/land_use_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/land_cover_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/soil_classification_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/major_landform_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/slope_position_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/sky_conditions_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/ground_conditions_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/soil_preparation_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape/observation_lucc_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/select/select_data_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/pandas/pandas_inspect_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/plot/plot_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/outlier_detection_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/variance_threshold_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/chemometrics_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/filter_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/multi-filter_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/agglomeration_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/spectra_univariate_indicator_selection_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/regression_models_v10_sql.json
#
#     reading JSON:
#     /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/spectra_indicator_permutation_selection_v10_sql.json
#
# ########### STARTING PROCESSES ###########
#
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/root_process/root_processes_v10_sql.json
# . (2 ready processes to run)
#
# . Running process nr: 0 add_root_process
# .   Adding root process: manage_table_data
#     ✅ Root process manage_table_data inserted
#
# . Running process nr: 1 add_root_process
# .   Adding root process: translate_data
#     ✅ Root process translate_data inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/translate/translate_tabular_data_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: translate_tabular_data
#  ✅ Sub process translate_tabular_data inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/translate/insert_tabular_data_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: insert_tabular_data
#  ✅ Sub process insert_tabular_data inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/utility/foreign_key_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_foreign_key
#  ✅ Sub process manage_foreign_key inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/utility/territory_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_territory
#  ✅ Sub process manage_territory inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/community/organisation_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_organisation
#  ✅ Sub process manage_organisation inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/community/user_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_user
#  ✅ Sub process manage_user inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/analysis_method_translate_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_analysis_method_translate
#  ✅ Sub process manage_analysis_method_translate inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/analysis_method_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_analysis_method
#  ✅ Sub process manage_analysis_method inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/apparatus_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_apparatus
#  ✅ Sub process manage_apparatus inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/classification_v10_sql.json
# . (5 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_order
#  ✅ Sub process manage_order inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: manage_family
#  ✅ Sub process manage_family inserted
#
# . Running process nr: 2 add_process
# .   Adding sub process: manage_genus
#  ✅ Sub process manage_genus inserted
#
# . Running process nr: 3 add_process
# .   Adding sub process: manage_species
#  ✅ Sub process manage_species inserted
#
# . Running process nr: 4 add_process
# .   Adding sub process: manage_specimen
#  ✅ Sub process manage_specimen inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/indicator_default_unit_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_indicator_default_unit
#  ✅ Sub process manage_indicator_default_unit inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/indicator_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_indicator
#  ✅ Sub process manage_indicator inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/indicator_parity_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_indicator_parity
#  ✅ Sub process manage_indicator_parity inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/juxtaposition_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_juxtaposition
#  ✅ Sub process manage_juxtaposition inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/license_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_license
#  ✅ Sub process manage_license inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/location_method_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_location_method
#  ✅ Sub process manage_location_method inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/method_tier_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_method_tier
#  ✅ Sub process manage_method_tier inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/preparation_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_preparation
#  ✅ Sub process manage_preparation inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/preservation_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_preservation
#  ✅ Sub process manage_preservation inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/profiling_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_profiling
#  ✅ Sub process manage_profiling inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/provider_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_provider
#  ✅ Sub process manage_provider inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/provision_indicator_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_provision_indicator
#  ✅ Sub process manage_provision_indicator inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/provision_serial_nr_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_provision_serial_nr
#  ✅ Sub process manage_provision_serial_nr inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/provision_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_provision
#  ✅ Sub process manage_provision inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/quantity_default_unit_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_quantity_default_unit
#  ✅ Sub process manage_quantity_default_unit inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/quantity_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_quantity
#  ✅ Sub process manage_quantity inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/setting_system_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_setting_system
#  ✅ Sub process manage_setting_system inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/spatial_reference_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_spatial_reference
#  ✅ Sub process manage_spatial_reference inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/spectrometer_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_spectrometer
#  ✅ Sub process manage_spectrometer inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/spectroscopy_method_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_spectroscopy_method
#  ✅ Sub process manage_spectroscopy_method inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/storage_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_storage
#  ✅ Sub process manage_storage inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/transportation_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_transportation
#  ✅ Sub process manage_transportation inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/unit_translate_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_unit_translate
#  ✅ Sub process manage_unit_translate inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/unit_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_unit
#  ✅ Sub process manage_unit inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_sequence_library_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: edna_sequence_library
#  ✅ Sub process edna_sequence_library inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_nucleotide_archive_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_edna_nucleotide_archive
#  ✅ Sub process manage_edna_nucleotide_archive inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_extraction_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_edna_extraction
#  ✅ Sub process manage_edna_extraction inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_purification_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_edna_purification
#  ✅ Sub process manage_edna_purification inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_sequencing_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_edna_sequencing
#  ✅ Sub process manage_edna_sequencing inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation_utility/edna_metabarcoding_pipeline_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_edna_metabarcoding_pipeline
#  ✅ Sub process manage_edna_metabarcoding_pipeline inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/campaign_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_campaign
#  ✅ Sub process manage_campaign inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/dataset_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_dataset
#  ✅ Sub process manage_dataset inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/measurement_v10_sql.json
# . (2 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_measurement_array
#  ✅ Sub process manage_measurement_array inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: manage_measurement
#  ✅ Sub process manage_measurement inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/observation_log_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_observation_log
#  ✅ Sub process manage_observation_log inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/observation_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_observation
#  ✅ Sub process manage_observation inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/data_source_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_data_source
#  ✅ Sub process manage_data_source inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/person_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_person
#  ✅ Sub process manage_person inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/sample_v10_sql.json
# . (5 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_simple_sample
#  ✅ Sub process manage_simple_sample inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: manage_geo_sample
#  ✅ Sub process manage_geo_sample inserted
#
# . Running process nr: 2 add_process
# .   Adding sub process: manage_geolocated_sample
#  ✅ Sub process manage_geolocated_sample inserted
#
# . Running process nr: 3 add_process
# .   Adding sub process: manage_geo_profile_sample
#  ✅ Sub process manage_geo_profile_sample inserted
#
# . Running process nr: 4 add_process
# .   Adding sub process: manage_geolocated_profile_sample
#  ✅ Sub process manage_geolocated_profile_sample inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/sample_geolocation_v10_sql.json
# . (2 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_geolocation
#  ✅ Sub process manage_geolocation inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: manage_sample_geotag
#  ✅ Sub process manage_sample_geotag inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/sampling_log_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process (overwriting)
# .   Overwriting sub process: manage_sampling_log
#  ✅ Sub process manage_sampling_log inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/campaign_tag_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_campaign_tag
#  ✅ Sub process manage_campaign_tag inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/observation/dataset_tag_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_dataset_tag
#  ✅ Sub process manage_dataset_tag inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/crop_growth_stage_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_crop_growth_stage
#  ✅ Sub process manage_crop_growth_stage inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/land_use_v10_sql.json
# . (3 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_landuse_order
#  ✅ Sub process manage_landuse_order inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: manage_landuse_family
#  ✅ Sub process manage_landuse_family inserted
#
# . Running process nr: 2 add_process
# .   Adding sub process: manage_landuse_genus
#  ✅ Sub process manage_landuse_genus inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/land_cover_v10_sql.json
# . (3 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_landcover_order
#  ✅ Sub process manage_landcover_order inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: manage_landcover_family
#  ✅ Sub process manage_landcover_family inserted
#
# . Running process nr: 2 add_process
# .   Adding sub process: manage_landcover_genus
#  ✅ Sub process manage_landcover_genus inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/soil_classification_v10_sql.json
# . (3 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_soil_texture_usda
#  ✅ Sub process manage_soil_texture_usda inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: manage_soil_texture_isss
#  ✅ Sub process manage_soil_texture_isss inserted
#
# . Running process nr: 2 add_process
# .   Adding sub process: manage_reference_soil_groups
#  ✅ Sub process manage_reference_soil_groups inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/major_landform_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_major_landform
#  ✅ Sub process manage_major_landform inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/slope_position_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_slope_position
#  ✅ Sub process manage_slope_position inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/sky_conditions_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_sky_condition
#  ✅ Sub process manage_sky_condition inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/ground_conditions_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_ground_condition
#  ✅ Sub process manage_ground_condition inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape_utility/soil_preparation_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_soil_preparation
#  ✅ Sub process manage_soil_preparation inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/landscape/observation_lucc_v10_sql.json
# . (2 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: manage_land_cover_observation
#  ✅ Sub process manage_land_cover_observation inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: manage_land_use_observation
#  ✅ Sub process manage_land_use_observation inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/select/select_data_v10_sql.json
# . (3 ready processes to run)
#
# . Running process nr: 0 add_root_process
# .   Adding root process: select_data
#     ✅ Root process select_data inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: select_spectra
#  ✅ Sub process select_spectra inserted
#
# . Running process nr: 2 add_process
# .   Adding sub process: select_indicator
#  ✅ Sub process select_indicator inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/pandas/pandas_inspect_v10_sql.json
# . (2 ready processes to run)
#
# . Running process nr: 0 add_root_process (overwriting)
# .   Overwriting root process: pandas
#     ✅ Root process pandas inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: inspect_pandas_dataset
#  ✅ Sub process inspect_pandas_dataset inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/plot/plot_v10_sql.json
# . (5 ready processes to run)
#
# . Running process nr: 0 add_root_process
# .   Adding root process: plot
#     ✅ Root process plot inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: plot_indicators
#  ✅ Sub process plot_indicators inserted
#
# . Running process nr: 2 add_process
# .   Adding sub process: plot_spectra
#  ✅ Sub process plot_spectra inserted
#
# . Running process nr: 3 add_process
# .   Adding sub process: plot_spectra_scattercorrection_scalers
#  ✅ Sub process plot_spectra_scattercorrection_scalers inserted
#
# . Running process nr: 4 add_process
# .   Adding sub process: plot_spectra_scaling_methods
#  ✅ Sub process plot_spectra_scaling_methods inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/outlier_detection_v10_sql.json
# . (2 ready processes to run)
#
# . Running process nr: 0 add_root_process
# .   Adding root process: machine_learning
#     ✅ Root process machine_learning inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: detect_outliers
#  ✅ Sub process detect_outliers inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/variance_threshold_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: select_variance_threshold
#  ✅ Sub process select_variance_threshold inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/chemometrics_v10_sql.json
# . (5 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: chemometric_default
#  ✅ Sub process chemometric_default inserted
#
# . Running process nr: 1 add_process
# .   Adding sub process: spectra_derivative
#  ✅ Sub process spectra_derivative inserted
#
# . Running process nr: 2 add_process
# .   Adding sub process: spectra_scatter_correction
#  ✅ Sub process spectra_scatter_correction inserted
#
# . Running process nr: 3 add_process
# .   Adding sub process: spectra_scaling
#  ✅ Sub process spectra_scaling inserted
#
# . Running process nr: 4 add_process
# .   Adding sub process: spectra_decomposition
#  ✅ Sub process spectra_decomposition inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/filter_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: filter_spectra
#  ✅ Sub process filter_spectra inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/multi-filter_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: multi_filter_spectra
#  ✅ Sub process multi_filter_spectra inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/agglomeration_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: ward_clustering
#  ✅ Sub process ward_clustering inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/spectra_univariate_indicator_selection_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: spectra_indicator_univariate_selection
#  ✅ Sub process spectra_indicator_univariate_selection inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/regression_models_v10_sql.json
# . (2 ready processes to run)
#
# . Running process nr: 0 add_root_process
# .   Adding root process: machine_learning
#     ✅ Root process machine_learning already exists
#
# . Running process nr: 1 add_process
# .   Adding sub process: regression_modeling
#  ✅ Sub process regression_modeling inserted
# . Command file: /Users/thomasgumbricht/GitHub_xspatula/xspatula_lucas/setup/zzz/lucas/setup_processes/json/machine_learning/spectra_indicator_permutation_selection_v10_sql.json
# . (1 ready processes to run)
#
# . Running process nr: 0 add_process
# .   Adding sub process: spectra_indicator_permutation_selection
#  ✅ Sub process spectra_indicator_permutation_selection inserted
